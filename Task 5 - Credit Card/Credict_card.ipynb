# %% [markdown]
# <h1>Task 1 - Credict Card Fraud dection</h1>
# <ul>
#   <li>Industry - CodeSoft</li>
#   <li>Contribution - Individual</li>
#   <li>Member Name - Krishi Devani</li>
#   <li>Task - 5</li>
# </ul>

# %% [markdown]
# <h2>Importing The Dependencies</h2>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# <h2>Data Collection & Processing</h2>

# %%
#Load the data from csv files to pandas DataFrame
df = pd.read_csv("creditcard.csv")

# %%
# Printing the first 5 Row of the dataframe
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5     2 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6     4  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7     7 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8     7 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9     9 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
# Numbers of Rows and Columns in dataset
print(f"Numbers of Rows : {df.shape[0]}")
print(f"Numbers of Columns : {df.shape[1]}")
# Out:
# Numbers of Rows : 5974
# Numbers of Columns : 31

# %%
# Getting Some imformation about data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5974 entries, 0 to 5973
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    5974 non-null   int64
#  1   V1      5974 non-null   float64
#  2   V2      5974 non-null   float64
#  3   V3      5974 non-null   float64
#  4   V4      5974 non-null   float64
#  5   V5      5974 non-null   float64
#  6   V6      5974 non-null   float64
#  7   V7      5974 non-null   float64
#  8   V8      5974 non-null   float64
#  9   V9      5974 non-null   float64
#  10  V10     5974 non-null   float64
#  11  V11     5974 non-null   float64
#  12  V12     5974 non-null   float64
#  13  V13     5974 non-null   float64
#  14  V14     5974 non-null   float64
#  15  V15     5974 non-null   float64
#  16  V16     5974 non-null   float64
#  17  V17     5974 non-null   float64
#  18  V18     5973 non-null   float64
#  19  V19     5973 non-null   float64
# ...

# %%
# Check the number of missing values in each columns
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
# Finding the number of people survied and not survived
df['Class'].value_counts()
# Out:
# Class
# 0.0    5970
# 1.0       3
# Name: count, dtype: int64

# %%
# separating the data for analysis
legit = df[df.Class == 0]
fraud = df[df.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (5970, 31)
# (3, 31)

# %%
fraud.Amount.describe()
# Out:
# count      3.000000
# mean     256.310000
# std      264.880121
# min        0.000000
# 25%      119.965000
# 50%      239.930000
# 75%      384.465000
# max      529.000000
# Name: Amount, dtype: float64

# %%
# compare the values for both transactions
df.groupby('Class').mean()
# Out:
#              Time        V1        V2        V3        V4        V5        V6  \
# Class
# 0.0    2677.40201 -0.264965  0.285625  0.844580  0.102656  0.000958  0.195420
# 1.0    1780.00000 -2.553039  0.184644 -0.293711  2.872264  0.005330 -0.855718
#
#              V7        V8        V9  ...       V20       V21       V22  \
# Class                                ...
# 0.0    0.018542 -0.039195  0.397472  ...  0.055426 -0.043268 -0.161540
# 1.0   -0.549831  0.308239 -1.093098  ...  0.599742  0.294921 -0.177321
#
#             V23       V24       V25       V26       V27       V28      Amount
# Class
# 0.0   -0.036683  0.028985  0.089890 -0.040132  0.025238  0.006163   64.965707
# 1.0    0.361160 -0.020311  0.056068 -0.170050  0.015979 -0.086847  256.310000
#
# [2 rows x 30 columns]

# %%
legit_sample = legit.sample(n=492)

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 5660  5909  1.302762  0.331127  0.201640  0.427880  0.282969  0.063495
# 3086  2644  1.239660  0.322964  0.806136  0.986430 -0.324209 -0.304823
# 4979  4543  1.260466 -0.040997  0.255452  0.717149 -0.021413  0.419798
# 1672  1297 -2.577786 -0.871437 -0.648350 -0.197175  4.151736  2.516792
# 1598  1246 -0.484811  1.012835  1.233358  1.053085  0.503789 -1.407947
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 5660 -0.110961 -0.104129  1.044264  ... -0.424806 -0.975856 -0.017020
# 3086 -0.167178 -0.118922  0.102324  ... -0.071424 -0.088779 -0.023377
# 4979 -0.410283  0.091149  1.864155  ... -0.272895 -0.373450 -0.224969
# 1672 -1.766533 -0.832705 -0.099199  ...  1.036031 -1.378481 -0.342906
# 1598  1.100313 -0.366127 -1.156819  ...  0.197451  0.572602 -0.130716
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.tail()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 4749  4192  1.064117 -1.020751  1.416967 -0.366313 -1.739746 -0.058274
# 5299  5174 -1.099540 -0.139671  1.623854 -0.310035 -2.252651  1.374979
# 541    406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 4749 -1.251443  0.021027  0.661497  ... -0.181514 -0.014493 -0.039470
# 5299  1.806673 -0.195528  1.350469  ... -0.159353  0.002188  0.184613
# 541  -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623   0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 4920  0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    492
# 1.0      3
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#              Time        V1        V2        V3        V4        V5        V6  \
# Class
# 0.0    2574.20122 -0.314980  0.291171  0.801934  0.118143  0.025909  0.249135
# 1.0    1780.00000 -2.553039  0.184644 -0.293711  2.872264  0.005330 -0.855718
#
#              V7        V8        V9  ...       V20       V21       V22  \
# Class                                ...
# 0.0    0.008520  0.001945  0.418653  ...  0.046824  0.025877 -0.176432
# 1.0   -0.549831  0.308239 -1.093098  ...  0.599742  0.294921 -0.177321
#
#             V23       V24       V25       V26       V27       V28      Amount
# Class
# 0.0   -0.056967  0.046298  0.111446 -0.074416  0.004139  0.011366   71.013902
# 1.0    0.361160 -0.020311  0.056068 -0.170050  0.015979 -0.086847  256.310000
#
# [2 rows x 30 columns]

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
print(Y)
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 5660  5909  1.302762  0.331127  0.201640  0.427880  0.282969  0.063495
# 3086  2644  1.239660  0.322964  0.806136  0.986430 -0.324209 -0.304823
# 4979  4543  1.260466 -0.040997  0.255452  0.717149 -0.021413  0.419798
# 1672  1297 -2.577786 -0.871437 -0.648350 -0.197175  4.151736  2.516792
# 1598  1246 -0.484811  1.012835  1.233358  1.053085  0.503789 -1.407947
# ...    ...       ...       ...       ...       ...       ...       ...
# 4749  4192  1.064117 -1.020751  1.416967 -0.366313 -1.739746 -0.058274
# 5299  5174 -1.099540 -0.139671  1.623854 -0.310035 -2.252651  1.374979
# 541    406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
#
#             V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (495, 30) (396, 30) (99, 30)

# %%
model = LogisticRegression()
# training the Logistic Regression Model with Training Data
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  1.0

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.98989898989899
